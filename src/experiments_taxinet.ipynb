# %%
print("WHAT")
# Out:
# WHAT

# %%
raise Exception("YOU SHOULD SEE THIS")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 raise Exception("YOU SHOULD SEE THIS")
#
# Exception: YOU SHOULD SEE THIS

# %%
import os
from types import SimpleNamespace

import simulators.NASA_ULI_Xplane_Simulator.src.simulation.run_sim2 as run_sim
import simulators.NASA_ULI_Xplane_Simulator.src.simulation.plot_sim as plot_sim

import warnings
warnings.filterwarnings("ignore", category=ResourceWarning)
warnings.filterwarnings("ignore", category=PendingDeprecationWarning)
warnings.filterwarnings("ignore", category=UserWarning)
# Out:
# found device:  cpu
# /home/nick/code/hjnnv/src/simulators/NASA_ULI_Xplane_Simulator/src/attack/train_static_dnn.py:440: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm as tqdm

# %%
# raise RuntimeError("CELL RAN")
rerun_experiments = False  # Set to True to rerun simulations

if rerun_experiments:
    results_dir = run_sim.main()
else:
    results_dir = '/home/nick/code/hjnnv/data/scratch/NASA_ULI_Xplane_Simulator/logs/LOG_20251027_16_06_01_GOOD/'
    print(results_dir)
print("WHAT")
# Out:
# /home/nick/code/hjnnv/data/scratch/NASA_ULI_Xplane_Simulator/logs/LOG_20251027_16_06_01_GOOD/
# WHAT

# %%
results_file = os.path.basename(os.path.normpath(results_dir))
args = SimpleNamespace(
    file=results_file,
    aux_file='LOG_20251027_16_07_13_GOOD',
    plot_type="trajectory",
    plot_u=False,
    cbar=False,
)
plot_sim.plot_sim(args)

# %%
results_file = os.path.basename(os.path.normpath(results_dir))
args = SimpleNamespace(
    file=results_file,
    aux_file='LOG_20251027_16_07_13_GOOD',
    plot_type="trajectory",
    plot_u=False,
    cbar=False,
)
plot_sim.plot_sim(args)

# %%
results_file = os.path.basename(os.path.normpath(results_dir))
